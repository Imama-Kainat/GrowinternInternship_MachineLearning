# %% [markdown]
# <a href="https://colab.research.google.com/github/Imama-Kainat/Growintern_internship_machine-learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Description: This program attempts to perdict the future price of stock

# %%
#import the libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestRegressor
import matplotlib.pyplot as plt

# %%
#collect and clean data: df ->data frame
df = pd.read_csv('stockdata.csv')
df = df.dropna()
#look at the data
df
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2022-12-16  288.760010  294.720001  288.700012  290.709991  290.709991
# 1    2022-12-19  289.730011  292.250000  286.130005  288.299988  288.299988
# 2    2022-12-20  281.239990  289.279999  280.809998  288.190002  288.190002
# 3    2022-12-21  289.989990  300.660004  286.500000  297.959991  297.959991
# 4    2022-12-22  298.089996  298.880005  290.809998  297.750000  297.750000
# ..          ...         ...         ...         ...         ...         ...
# 246  2023-12-11  459.359985  470.649994  457.209991  459.890015  459.890015
# 247  2023-12-12  465.230011  465.609985  459.200012  463.000000  463.000000
# 248  2023-12-13  461.980011  481.250000  461.980011  479.980011  479.980011
# 249  2023-12-14  480.359985  480.760010  464.760010  469.829987  469.829987
# 250  2023-12-15  467.299988  473.000000  467.299988  472.059998  472.059998
#
#        Volume
# 0    14080000
# 1     6163700
# ...

# %%
# show the data visually
df.plot(x="Date", y="Close")
plt.xticks(rotation=45)
# Out:
# (array([-50.,   0.,  50., 100., 150., 200., 250., 300.]),
#  [Text(-50.0, 0, '2023-10-06'),
#   Text(0.0, 0, '2022-12-16'),
#   Text(50.0, 0, '2023-03-02'),
#   Text(100.0, 0, '2023-05-12'),
#   Text(150.0, 0, '2023-07-26'),
#   Text(200.0, 0, '2023-10-05'),
#   Text(250.0, 0, '2023-12-15'),
#   Text(300.0, 0, '')])

# %%
#Create the model
model= RandomForestRegressor()

# %%
#train the model
X=df[['Open', 'High','Low','Volume']]
X= X[:int(len(df)-1)]
y=df['Close']
y=y[:int(len(df)-1)]
model.fit(X,y) # training the model
# Out:
# RandomForestRegressor()

# %%
#Test the model
predicions=model.predict(X)
print('The model score is :', model.score(X,y))
# Out:
# The model score is : 0.9991964601774501

# %%
#Make the predictions
new_data=df[['Open', 'High','Low','Volume']].tail(1)
prediction = model.predict(new_data)
print('The model predicts the last row or day to be:',prediction)
print('Actual value is:',df[['Close']].tail(1).values[0][0])
# Out:
# The model predicts the last row or day to be: [466.68669854]
# Actual value is: 472.059998
